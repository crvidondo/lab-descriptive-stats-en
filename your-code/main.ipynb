# %% [markdown]
# # Before you start :
#    - These exercises are related to the Subsetting and Descriptive Stats lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
# import libraries here

import pandas as pd
import numpy as np

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### In this challenge we will use the `Temp_States.csv` file.
#
# #### First import it into a data frame called `temp`.

# %%
temp = pd.read_csv("Temp_States.csv")

# %% [markdown]
# #### Print `temp`

# %%
temp
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the Temp dataframe. What type of data do we have? Comment your result.

# %%
temp.dtypes
"""" We have strings for City and State and float for Temperature in each city"""
# Out:
# '" We have strings for City and State and float for Temperature in each city'

# %% [markdown]
# #### Select the rows where state is New York

# %%
new_york_rows = temp[temp["State"] == "New York"]
new_york_rows
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### What is the average of the temperature of cities in New York?

# %%
new_york_rows["Temperature"].mean()
# Out:
# 10.74074074074074

# %% [markdown]
# #### We want to know cities and states with Temperature above 15 degress Celcius

# %%
above15 = temp[temp["Temperature"] > 15]
above15
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222
# 5    Treton   New Jersey    22.222222
# 6    Newark   New Jersey    20.000000

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degress Celcius

# %%
above15[["City"]]
# Out:
#        City
# 0       NYC
# 3  Hartford
# 5    Treton
# 6    Newark

# %% [markdown]
# #### We want to know which cities have a temperature above 15 degrees Celcius and below 20 degrees Celcius
#
# *Hint: First write the condition then select the rows.*

# %%
above15_below20 = temp[(temp["Temperature"] > 15) & (temp["Temperature"] < 20)]
above15_below20
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222

# %% [markdown]
# #### Find the mean and the standard deviation of the temperature of each state.
#
# *Hint: Use functions from Data Manipulation lesson*

# %%
# Mean
temp[["State", "Temperature"]].groupby(by="State").mean()
# Out:
#              Temperature
# State
# Connecticut    15.833333
# New Jersey     21.111111
# New York       10.740741

# %%
# Standard deviation
temp[["State", "Temperature"]].groupby(by="State").std()
# Out:
#              Temperature
# State
# Connecticut     1.964186
# New Jersey      1.571348
# New York        8.133404

# %%
# Both together
temp[["Temperature", "State"]].groupby(by="State").agg(['mean', 'std'])
# Out:
#             Temperature
#                    mean       std
# State
# Connecticut   15.833333  1.964186
# New Jersey    21.111111  1.571348
# New York      10.740741  8.133404

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Load the `employee.csv` file into a DataFrame. Call the dataframe `employee`

# %%
employee = pd.read_csv("Employee.csv")
employee
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 6  Carlos         IT    Master      M         VP      8      70
# 7   Pedro         IT       Phd      M  associate      7      60
# 8     Ana         HR    Master      F         VP      8      70

# %% [markdown]
# #### Explore the data types of the Temp dataframe. Comment your results

# %%
employee.dtypes
""" They are all strings but years and salary that are integers """
# Out:
# ' They are all strings but years and salary that are integers '

# %% [markdown]
# #### Show visually the frequency distribution (histogram) of the employee dataset. In few words describe these histograms?

# %%
import matplotlib.pyplot as plt

# %%
# Select numerical columns
# Create histograms for each numerical column
employee.hist(bins=10, edgecolor='black')

# Set overall title
plt.suptitle('Frequency Distribution of Years and Salary', fontsize=16)

# Display the plots
plt.show()

# %%
""" Years of service histogram show a higher frequency at lower years of service.
    Salary histogram display more employees in the higher salary ranges."""
# Out:
# ' Years of service histogram show a higher frequency at lower years of service.\n    Salary histogram display more employees in the higher salary ranges.'

# %% [markdown]
# #### What's the average salary in this company?

# %%
employee[["Salary"]].mean()
# Out:
# Salary    48.888889
# dtype: float64

# %% [markdown]
# #### What's the highest salary?

# %%
employee[["Salary"]].max()
# Out:
# Salary    70
# dtype: int64

# %% [markdown]
# #### What's the lowest salary?

# %%
employee[["Salary"]].min()
# Out:
# Salary    30
# dtype: int64

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
lowest_salary = employee["Salary"].min()
emp_low = employee[employee["Salary"] == lowest_salary]
emp_low
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give all the information about an employee called David?

# %%
david = employee[employee["Name"] == "David"]
david
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give only David's salary?

# %%
david["Salary"]
# Out:
# 2    30
# Name: Salary, dtype: int64

# %% [markdown]
# #### Print all the rows where job title is associate

# %%
associate = employee[employee["Title"] == "associate"]
associate
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 7   Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Print the first 3 rows of your dataframe
#
# ##### Tip : There are 2 ways to do it. Do it both ways

# %%
employee.head(3)
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %%
employee[0:3]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Find the employees who's title is associate and the salary above 55?

# %%
employee[(employee["Title"]  == "associate") & (employee["Salary"] > 55)]
# Out:
#     Name Department Education Gender      Title  Years  Salary
# 7  Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Group the employees based on their number of years of employment. What are the average salaries in each group?

# %%
employee[["Years", "Salary"]].groupby(by="Years").mean()
# Out:
#           Salary
# Years
# 1      35.000000
# 2      38.333333
# 3      55.000000
# 4      35.000000
# 7      60.000000
# 8      70.000000

# %% [markdown]
# ####  What is the average Salary per title?

# %%
employee[["Title", "Salary"]].groupby(by="Title").mean()
# Out:
#               Salary
# Title
# VP         70.000000
# analyst    32.500000
# associate  56.666667

# %% [markdown]
# #### Show a visual summary of the data using boxplot. What Are the First and Third Quartiles? Comment your results.
#
# * Hint : Quantiles vs Quartiles*
# In Probability and Statistics, quantiles are cut points dividing the range of a probability distribution into continuous intervals with equal probabilities. When division is into four parts the values of the variate corresponding to 25%, 50% and 75% of the total distribution are called quartiles.

# %%
employee.boxplot()
# Out:
# <Axes: >

# %%
first_quant_s = employee["Salary"].quantile(0.25)
first_quant_y = employee["Years"].quantile(0.25)
print(f"First quartile in Salary is: {first_quant_s}")
print(f"First quartile in Years is: {first_quant_y}")
# Out:
# First quartile in Salary is: 35.0
# First quartile in Years is: 2.0

# %%
third_quant_s = employee["Salary"].quantile(0.75)
third_quant_y = employee["Years"].quantile(0.25)
print(f"Third quartile in Salary is: {third_quant_s}")
print(f"Third quartile in Years is: {third_quant_y}")
# Out:
# Third quartile in Salary is: 60.0
# Third quartile in Years is: 2.0

# %% [markdown]
# #### Is the mean salary per gender different?

# %%
employee[["Gender", "Salary"]].groupby(by="Gender").mean()
# Out:
#         Salary
# Gender
# F         47.5
# M         50.0

# %% [markdown]
# #### Find the minimum, mean and the maximum of all numeric columns for each Department.
#
# ##### Hint: Use functions from Data Manipulation lesson

# %%
employee[["Department", "Years", "Salary"]].groupby(by="Department").agg(["min", "max", "mean"])
# Out:
#            Years               Salary
#              min max      mean    min max   mean
# Department
# HR             2   8  4.666667     30  70  45.00
# IT             1   8  4.500000     30  70  48.75
# Sales          2   3  2.500000     55  55  55.00

# %% [markdown]
# ### Bonus Question
#
# #### For each department, compute the difference between the maximal salary and the minimal salary.
#
# ##### * Hint: try using `agg` or `apply` and `lambda`*

# %%
employee[["Department", "Salary"]].groupby(by="Department").agg(lambda x: x.max() - x.min())
# Out:
#             Salary
# Department
# HR              40
# IT              40
# Sales            0

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Open the Orders.csv dataset. Name your dataset orders

# %%
orders = pd.read_csv("Orders.csv")
orders
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0                0     536365    85123A  2010     12    3     8
# 1                1     536365     71053  2010     12    3     8
# 2                2     536365    84406B  2010     12    3     8
# 3                3     536365    84029G  2010     12    3     8
# 4                4     536365    84029E  2010     12    3     8
# ...            ...        ...       ...   ...    ...  ...   ...
# 397919      541904     581587     22613  2011     12    5    12
# 397920      541905     581587     22899  2011     12    5    12
# 397921      541906     581587     23254  2011     12    5    12
# 397922      541907     581587     23255  2011     12    5    12
# 397923      541908     581587     22138  2011     12    5    12
#
#                                 Description  Quantity          InvoiceDate  \
# 0        white hanging heart t-light holder         6  2010-12-01 08:26:00
# ...

# %% [markdown]
# #### Explore your dataset by looking at the data types and the summary statistics. Comment your results

# %%
orders.describe()
# Out:
#           Unnamed: 0      InvoiceNo           year          month  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean   278465.221859  560617.126645    2010.934259       7.612537
# std    152771.368303   13106.167695       0.247829       3.416527
# min         0.000000  536365.000000    2010.000000       1.000000
# 25%    148333.750000  549234.000000    2011.000000       5.000000
# 50%    284907.500000  561893.000000    2011.000000       8.000000
# 75%    410079.250000  572090.000000    2011.000000      11.000000
# max    541908.000000  581587.000000    2011.000000      12.000000
#
#                  day           hour       Quantity      UnitPrice  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean        3.614555      12.728247      13.021823       3.116174
# std         1.928274       2.273535     180.420210      22.096788
# min         1.000000       6.000000       1.000000       0.000000
# ...

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397924 entries, 0 to 397923
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    397924 non-null  int64
#  1   InvoiceNo     397924 non-null  int64
#  2   StockCode     397924 non-null  object
#  3   year          397924 non-null  int64
#  4   month         397924 non-null  int64
#  5   day           397924 non-null  int64
#  6   hour          397924 non-null  int64
#  7   Description   397924 non-null  object
#  8   Quantity      397924 non-null  int64
#  9   InvoiceDate   397924 non-null  object
#  10  UnitPrice     397924 non-null  float64
#  11  CustomerID    397924 non-null  int64
#  12  Country       397924 non-null  object
#  13  amount_spent  397924 non-null  float64
# dtypes: float64(2), int64(8), object(4)
# memory usage: 42.5+ MB

# %% [markdown]
# ####  What is the average Purchase Price?

# %%
orders["amount_spent"].mean()
# Out:
# 22.394748504739596

# %% [markdown]
# #### What were the highest and lowest purchase prices?

# %%
orders["amount_spent"].agg(["max", "min"])
# Out:
# max    168469.6
# min         0.0
# Name: amount_spent, dtype: float64

# %% [markdown]
# #### Select all the customers we have in Spain

# %%
spanish = orders[orders["Country"] == "Spain"]
spanish
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 4250          6421     536944     22383  2010     12    5    12
# 4251          6422     536944     22384  2010     12    5    12
# 4252          6423     536944     20727  2010     12    5    12
# 4253          6424     536944     20725  2010     12    5    12
# 4254          6425     536944     20728  2010     12    5    12
# ...            ...        ...       ...   ...    ...  ...   ...
# 394733      535271     581193     23291  2011     12    3    17
# 394734      535272     581193    85232D  2011     12    3    17
# 394735      535273     581193     22721  2011     12    3    17
# 394736      535274     581193     23241  2011     12    3    17
# 394737      535275     581193     23247  2011     12    3    17
#
#                           Description  Quantity          InvoiceDate  \
# 4250          lunch bag suki  design         70  2010-12-03 12:20:00
# ...

# %% [markdown]
# #### How many customers do we have in Spain?
# ##### Hint : Use value_counts()

# %%
spanish["CustomerID"].nunique()
# Out:
# 30

# %% [markdown]
# #### Select all the customers who have bought more than 50 items ?

# %%
above50 = orders[orders["Quantity"] > 50]
above50[["CustomerID", "Quantity"]]
# Out:
#         CustomerID  Quantity
# 46           13748        80
# 83           15291        64
# 96           14688       120
# 102          14688        96
# 174          16029       100
# ...            ...       ...
# 397720       18102       144
# 397721       16626        84
# 397729       16626       144
# 397761       15311        96
# 397882       13777        72
#
# [11609 rows x 2 columns]

# %% [markdown]
# #### Select orders from Spain that are above 50 items

# %%
orders_spain = orders[orders["Country"] == "Spain"]
orders_spain[orders_spain["Quantity"] > 50]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 4250          6421     536944     22383  2010     12    5    12
# 4251          6422     536944     22384  2010     12    5    12
# 4252          6423     536944     20727  2010     12    5    12
# 4253          6424     536944     20725  2010     12    5    12
# 4254          6425     536944     20728  2010     12    5    12
# 32454        52416     540785    84997B  2011      1    2    11
# 32455        52417     540785    84997D  2011      1    2    11
# 32456        52418     540785    84997C  2011      1    2    11
# 32457        52419     540785    84997A  2011      1    2    11
# 91155       136767     547972     22383  2011      3    1    16
# 91156       136768     547972     22384  2011      3    1    16
# 91159       136771     547972     20728  2011      3    1    16
# 174442      248797     558871     22384  2011      7    1    13
# 174443      248798     558871     20727  2011      7    1    13
# ...

# %% [markdown]
# #### Select all free orders

# %%
orders[orders["UnitPrice"] == 0]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 6914          9302     537197     22841  2010     12    7    14
# 22539        33576     539263     22580  2010     12    4    14
# 25379        40089     539722     22423  2010     12    2    13
# 29080        47068     540372     22090  2011      1    4    16
# 29082        47070     540372     22553  2011      1    4    16
# 34494        56674     541109     22168  2011      1    4    15
# 53788        86789     543599    84535B  2011      2    4    13
# 85671       130188     547417     22062  2011      3    3    10
# 92875       139453     548318     22055  2011      3    3    12
# 97430       145208     548871     22162  2011      4    1    14
# 107192      157042     550188     22636  2011      4    4    18
# 128641      187613     553000     47566  2011      5    4    15
# 137127      198383     554037     22619  2011      5    5    14
# 194648      279324     561284     22167  2011      7    2    12
# ...

# %% [markdown]
# #### Select all orders that are 'lunch bag'
# #### Hint: Use string functions

# %%
orders[orders["Description"].str.contains("lunch bag")]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour Description  \
# 0                0     536365    85123A  2010     12    3     8   lunch bag
# 1                1     536365     71053  2010     12    3     8   lunch bag
# 2                2     536365    84406B  2010     12    3     8   lunch bag
# 3                3     536365    84029G  2010     12    3     8   lunch bag
# 4                4     536365    84029E  2010     12    3     8   lunch bag
# ...            ...        ...       ...   ...    ...  ...   ...         ...
# 397919      541904     581587     22613  2011     12    5    12   lunch bag
# 397920      541905     581587     22899  2011     12    5    12   lunch bag
# 397921      541906     581587     23254  2011     12    5    12   lunch bag
# 397922      541907     581587     23255  2011     12    5    12   lunch bag
# 397923      541908     581587     22138  2011     12    5    12   lunch bag
#
# ...

# %% [markdown]
# #### Select all orders that are made in 2011 and are 'lunch bag'

# %%
date_condition = orders[orders["year"] == 2011]

date_condition[date_condition["Description"].str.contains("lunch bag")]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour Description  \
# 26160        42481     539993     22386  2011      1    2    10   lunch bag
# 26161        42482     539993     21499  2011      1    2    10   lunch bag
# 26162        42483     539993     21498  2011      1    2    10   lunch bag
# 26163        42484     539993     22379  2011      1    2    10   lunch bag
# 26164        42485     539993     20718  2011      1    2    10   lunch bag
# ...            ...        ...       ...   ...    ...  ...   ...         ...
# 397919      541904     581587     22613  2011     12    5    12   lunch bag
# 397920      541905     581587     22899  2011     12    5    12   lunch bag
# 397921      541906     581587     23254  2011     12    5    12   lunch bag
# 397922      541907     581587     23255  2011     12    5    12   lunch bag
# 397923      541908     581587     22138  2011     12    5    12   lunch bag
#
# ...

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.hist(orders_spain["amount_spent"], bins=100)
plt.title('Frequency Distribution of Amount Spent in Spain')
plt.xlabel('Amount Spent')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# #### Select all orders made in the month of August

# %%
august = orders[orders["month"] == 8]
august
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour Description  \
# 199475      285421     561904     22075  2011      8    1     8   lunch bag
# 199476      285422     561904    85049E  2011      8    1     8   lunch bag
# 199477      285423     561905     21385  2011      8    1     9   lunch bag
# 199478      285424     561905    84970L  2011      8    1     9   lunch bag
# 199479      285425     561905    84970S  2011      8    1     9   lunch bag
# ...            ...        ...       ...   ...    ...  ...   ...         ...
# 226483      320688     565067     22644  2011      8    3    17   lunch bag
# 226484      320689     565067     22645  2011      8    3    17   lunch bag
# 226485      320690     565067     22637  2011      8    3    17   lunch bag
# 226486      320691     565067     22646  2011      8    3    17   lunch bag
# 226487      320692     565067     22741  2011      8    3    17   lunch bag
#
# ...

# %% [markdown]
# #### Select how many orders are made by countries in the month of August
# ##### Hint: Use value_counts()

# %%
august["Country"].value_counts()
# Out:
# Country
# United Kingdom     23105
# Germany              795
# EIRE                 593
# France               569
# Netherlands          280
# Switzerland          267
# Spain                252
# Belgium              194
# Israel               171
# Channel Islands      140
# Australia            107
# Italy                 95
# Austria               88
# Norway                77
# Finland               61
# Malta                 55
# Portugal              41
# Sweden                40
# Unspecified           23
# Iceland               22
# Poland                17
# Denmark               16
# Canada                 5
# Name: count, dtype: int64

# %% [markdown]
# #### What's the  average amount of money spent by country

# %%
orders[["Country", "amount_spent"]].groupby(by="Country").mean()
# Out:
#                       amount_spent
# Country
# Australia               116.895620
# Austria                  25.624824
# Bahrain                  32.258824
# Belgium                  20.283772
# Brazil                   35.737500
# Canada                   24.280662
# Channel Islands          27.340160
# Cyprus                   22.134169
# Czech Republic           33.069600
# Denmark                  49.882474
# EIRE                     36.687745
# European Community       21.670833
# Finland                  32.913985
# France                   25.056827
# Germany                  25.311562
# Greece                   32.831172
# Iceland                  23.681319
# Israel                   29.119718
# Italy                    23.064960
# Japan                   116.561900
# Lebanon                  37.641778
# Lithuania                47.458857
# Malta                    24.335625
# Netherlands             120.798282
# Norway                   33.736418
# ...

# %% [markdown]
# #### What's the most expensive item?

# %%
orders[["Description", "UnitPrice"]].groupby(by="Description").max()
# Out:
#              UnitPrice
# Description
# lunch bag      8142.75

# %%
max_price = orders["UnitPrice"].max()

most_expensive_item = orders[orders["UnitPrice"] == max_price]

most_expensive_item[["Description", "UnitPrice"]]
# Out:
#        Description  UnitPrice
# 118352   lunch bag    8142.75

# %% [markdown]
# #### What was the average amount spent per year ?

# %%
orders[["year", "amount_spent"]].groupby(by="year").mean()
# Out:
#       amount_spent
# year
# 2010     21.892733
# 2011     22.430074
